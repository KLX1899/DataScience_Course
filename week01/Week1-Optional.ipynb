# %% [markdown]
# # 4t DigiNext Data & ML Bootcamp
#
# ## Week 1 - EDA
#
# ### Optional Practices

# %% [markdown]
# ---

# %% [markdown]
# ## Kaggle & YData Profiling:
#
# https://colab.research.google.com/drive/12Gwt2gzSk7yaAzsS66bQVZGsu9lWYpvZ?usp=sharing

# %% [markdown]
# ## Introduction to SQL:
#
# https://colab.research.google.com/drive/1GGwK8_HfNSA4dIWbT2S3L7-Gx2yzW7jS?usp=sharing
